# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('/content/rose_1024.tif')

if image is not None:
    print("Dimensions de l'image (hauteur, largeur, canaux) :", image.shape)
else:
    print("L'image n'a pas pu être chargée. Vérifiez le nom ou le chemin du fichier.")
# Out:
# Dimensions de l'image (hauteur, largeur, canaux) : (1024, 1024, 3)

# %%
image.shape
# Out:
# (1024, 1024, 3)

# %%
cv2_imshow(image)

pixel_0_0 = image[0, 0]
pixel_10_10 = image[10, 10]
pixel_15_30 = image[15, 30]
print("Valeur du pixel (0, 0) :", pixel_0_0)
print("Valeur du pixel (10, 10) :", pixel_10_10)
print("Valeur du pixel (15, 30) :", pixel_15_30)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>
# Valeur du pixel (0, 0) : [21 21 21]
# Valeur du pixel (10, 10) : [23 23 23]
# Valeur du pixel (15, 30) : [19 19 19]

# %%
# 3. Sauvegarder cette image avec un format different (par exemple png)
cv2.imwrite('/content/rose_1024.png', image)
print("Image sauvegardée en tant que 'rose_1024.png'.")
# Out:
# Image sauvegardée en tant que 'rose_1024.png'.
